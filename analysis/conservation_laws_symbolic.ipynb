# %%
from sympy import *
import itertools
import numpy as np

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from mycolorpy import colorlist as mcp
import matplotlib
font = {'family' : 'serif',
        'size'   : 14}

matplotlib.rc('font', **font)
matplotlib.rc('xtick', labelsize=14) 
matplotlib.rc('ytick', labelsize=14) 

# Enable LaTeX rendering
matplotlib.rcParams['text.usetex'] = True

# %%
v = Symbol('v')
N = 15
alpha=sqrt(2)

psis = []
for i in range(N):
    psis.append((2**i * factorial(i) * pi)**(-1/2) * hermite(i,v/alpha) * exp(-v**2/alpha**2))

# %%
v_a = - 5
v_b = 5 

xis = []
for i in range(N):
    xis.append(sqrt(2*i+1) * legendre(i, (2*v - (v_a+v_b))/(v_b - v_a)))

# %%
J_0 = []
for i in range(1, N) :
    J_0.append(integrate(psis[i]*xis[0], (v,v_a,v_b)).evalf())

# %%
J_0

# %%
fig, ax = plt.subplots()
plt.scatter(np.arange(1, N), J_0)
ax.set_yscale('symlog', linthresh=1e-4)
plt.grid()
